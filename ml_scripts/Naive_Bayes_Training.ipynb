# %% [markdown]
# # Naive Bayes Training Notebook

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read CSV Data

# %%
heart_attack_df = pd.read_csv("AI_training_data.csv")
heart_attack_df
# Out:
#      age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0     28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1     29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2     29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3     30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4     31    0   2      100  219   0       1     150     0      0.0     ?  ?
# ..   ...  ...  ..      ...  ...  ..     ...     ...   ...      ...   ... ..
# 289   52    1   4      160  331   0       0      94     1      2.5     ?  ?
# 290   54    0   3      130  294   0       1     100     1      0.0     2  ?
# 291   56    1   4      155  342   1       0     150     1      3.0     2  ?
# 292   58    0   2      180  393   0       0     110     1      1.0     2  ?
# 293   65    1   4      130  275   0       1     115     1      1.0     2  ?
#
#     thal  num
# 0      ?           0
# 1      ?           0
# 2      ?           0
# 3      6           0
# 4      ?           0
# ..   ...         ...
# 289    ?           1
# 290    ?           1
# 291    ?           1
# 292    7           1
# 293    ?           1
#
# [294 rows x 14 columns]

# %% [markdown]
# ## Clean up dataframe

# %% [markdown]
# Dropping data that we cannot use or simulate for our own project and renaming some columns.

# %%
heart_attack_df.drop('cp', inplace=True, axis=1)
heart_attack_df.drop('restecg', inplace=True, axis=1)
heart_attack_df.drop('exang', inplace=True, axis=1)
heart_attack_df.drop('oldpeak', inplace=True, axis=1)
heart_attack_df.drop('slope', inplace=True, axis=1)
heart_attack_df.drop('ca', inplace=True, axis=1)
heart_attack_df.drop('thal', inplace=True, axis=1)

heart_attack_df.rename(columns={"trestbps": "resting heart rate", "chol": "cholestrol", "fbs" : "fasting blood sugar > 120 mg/dl", "thalach" : "maximum heart rate achieved", "num" : "heart attack"}, inplace=True)

heart_attack_df
# Out:
#      age  sex resting heart rate cholestrol fasting blood sugar > 120 mg/dl  \
# 0     28    1                130        132                               0
# 1     29    1                120        243                               0
# 2     29    1                140          ?                               0
# 3     30    0                170        237                               0
# 4     31    0                100        219                               0
# ..   ...  ...                ...        ...                             ...
# 289   52    1                160        331                               0
# 290   54    0                130        294                               0
# 291   56    1                155        342                               1
# 292   58    0                180        393                               0
# 293   65    1                130        275                               0
#
#     maximum heart rate achieved  num
# 0                           185           0
# 1                           160           0
# 2                           170           0
# 3                           170           0
# 4                           150           0
# ..                          ...         ...
# 289                          94           1
# 290                         100           1
# 291                         150           1
# 292                         110           1
# 293                         115           1
#
# [294 rows x 7 columns]

# %% [markdown]
# Removing rows that are missing data and thus are useless for training.

# %%
heart_attack_df = heart_attack_df.apply(pd.to_numeric, errors='coerce')
heart_attack_df = heart_attack_df.dropna()
heart_attack_df
# Out:
#      age  sex  resting heart rate  cholestrol  \
# 0     28    1               130.0       132.0
# 1     29    1               120.0       243.0
# 3     30    0               170.0       237.0
# 4     31    0               100.0       219.0
# 5     32    0               105.0       198.0
# ..   ...  ...                 ...         ...
# 289   52    1               160.0       331.0
# 290   54    0               130.0       294.0
# 291   56    1               155.0       342.0
# 292   58    0               180.0       393.0
# 293   65    1               130.0       275.0
#
#      fasting blood sugar > 120 mg/dl  maximum heart rate achieved  num
# 0                                0.0                        185.0           0
# 1                                0.0                        160.0           0
# 3                                0.0                        170.0           0
# 4                                0.0                        150.0           0
# 5                                0.0                        165.0           0
# ..                               ...                          ...         ...
# 289                              0.0                         94.0           1
# 290                              0.0                        100.0           1
# 291                              1.0                        150.0           1
# 292                              0.0                        110.0           1
# 293                              0.0                        115.0           1
#
# [262 rows x 7 columns]

# %%
training_set = heart_attack_df.to_numpy()
training_set
# Out:
# array([[ 28.,   1., 130., ...,   0., 185.,   0.],
#        [ 29.,   1., 120., ...,   0., 160.,   0.],
#        [ 30.,   0., 170., ...,   0., 170.,   0.],
#        ...,
#        [ 56.,   1., 155., ...,   1., 150.,   1.],
#        [ 58.,   0., 180., ...,   0., 110.,   1.],
#        [ 65.,   1., 130., ...,   0., 115.,   1.]])
